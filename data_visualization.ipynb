# %%
import data_visualization
import importlib
importlib.reload(data_visualization)

import pandas as pd

# %%
jd_categories = pd.read_csv("jd.csv", header=None)[[0]]
jd_categories.columns = ["category"]
jd_categories.head()
# Out:
#             category
# 0  software+engineer
# 1  software+engineer
# 2  software+engineer
# 3  software+engineer
# 4  software+engineer

# %%
data_visualization.plot_column_frequency(jd_categories, "category", title='Category Counts', xlabel='Categories', ylabel='Frequency')

# %%
data_visualization.plot_corr_heatmap(pd.read_csv("bag_difficult_train.csv", header=None).drop(labels=0, axis=1)[1:])

# %%
data_visualization.plot_corr_heatmap(pd.read_csv("bag_easy_train.csv", header=None).drop(labels=0, axis=1)[1:])

# %%
data_visualization.plot_corr_heatmap(pd.read_csv("embedding_difficult_train.csv", header=None).drop(labels=0, axis=1)[1:])

# %%
data_visualization.plot_corr_heatmap(pd.read_csv("embedding_easy_train.csv", header=None).drop(labels=0, axis=1)[1:])
